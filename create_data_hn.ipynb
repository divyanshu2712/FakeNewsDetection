# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
df1=pd.read_csv('true_news.csv')
df1['label']='True'
df1.head()
df1.shape
# Out:
# (439, 5)

# %%
df2=pd.read_csv('fake_news.csv')
df2['label']='Fake'
df2.head()
df2.shape
# Out:
# (1241, 5)

# %%
frames=[df1,df2]
df=pd.concat(frames)
df5=shuffle(df)

# %%
df5
# Out:
#       Unnamed: 0                                  short_description  \
# 418          424   बूम पाय वीडिय 2011 किम जोंग-इल के अंतिम संस्कार
# 244          482  21 साल के भरत जाधव कथित ऊंच जात के आदम सिर्फ़ ...
# 1010        1019  अव डांडिय द्वार शेयर क्लिप कथित रुप बीजेप प्रम...
# 58            59  दाव लोग नागरिक संशोधन अधिनियम के ख़िलाफ़ प्रदर्श...
# 425          431  बूम वास्तविक भाषण वीडिय देख पाय राहुल गाँध गंद...
# ...          ...                                                ...
# 627          634  मोबाइल वीडिय गेम के वीडिय फुटेज़ सुलेमा अमेरिक ...
# 115          218  केंद्र सरकार के कृष क़ानून विरोध रह किसान छह म...
# 207          420  कनाड ब्रिटेन के अमेरिक लोग किसान के समर्थन विर...
# 1137        1146  वायरल फ़ेक पोस्ट नरेंद्र मोद हट के शिवलिंग चप्प...
# 875          882  बूम पाय मोइत्र यूएस होलोकॉस्ट मेमोरियल के पोस्...
#
#                                              full_title  \
# 418   क्य किम जोंग-उन के अंतिम संस्कार एक्सक्लूसिव व...
# ...

# %%
df5.to_csv('news_hn.csv')
